# %%
# !pip install mne

# %%
import numpy as np
import mne
edf = mne.io.read_raw_edf('/content/drive/My Drive/Tensorflow/PN01-1.edf')
header = ','.join(edf.ch_names)
np.savetxt('/content/drive/My Drive/Tensorflow/PN01-1.csv', edf.get_data().T, delimiter=',', header=header)
# Out:
# Extracting EDF parameters from /content/drive/My Drive/Tensorflow/PN01-1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
